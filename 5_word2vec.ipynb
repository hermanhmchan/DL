# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# %matplotlib notebook

# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name)).split()
  f.close()
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'of', 'term', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.715572
# Nearest to see: seebeck, microscope, pentecostalism, universidade, discernible, hyman, autistic, il,
# Nearest to between: luftwaffe, re, fayetteville, arousing, customize, dissociation, lamiaceae, marcellinus,
# Nearest to s: nva, hatred, consults, hissing, istanbul, ribosome, classified, mycelium,
# Nearest to years: theft, consequences, overheat, nightingale, reversible, pylons, intermission, samurai,
# Nearest to and: dealerships, ingrid, uplift, berkeley, moabite, frida, ribozymes, mod,
# Nearest to up: both, snapshot, essences, pediatrics, boudin, picnics, blamed, easton,
# Nearest to about: corum, ritz, abhidhamma, psychometric, acidic, flee, glockenspiel, eyeball,
# Nearest to called: jul, thicknesses, ineffable, luxembourgish, coastlines, consolidating, freighter, swelling,
# Nearest to zero: rrna, psychedelic, kirchhoff, kpa, dickens, make, attorneys, fredric,
# Nearest to have: coeducational, bordered, ketone, merlin, strafford, dilmun, exponents, rainey,
# Nearest to the: saracens, jurists, vella, corvettes, erickson, treachery, adel, recycling,
# Nearest to first: abet, kali, subfield, mosley, spat, cartoonists, beast, perp,
# Nearest to state: catan, wala, mammary, fluently, medicine, manu, swnts, goal,
# Nearest to known: plantae, prosecuting, ergaster, packers, wrapped, expansionism, cfcs, aberdeenshire,
# Nearest to people: oriented, girl, functionalism, kos, practicable, births, abuser, ruptured,
# Nearest to his: brook, wrinkled, signatures, gourd, photographic, librettist, baloch, gemara,
# Average loss at step 2000: 4.350753
# Average loss at step 4000: 3.857883
# Average loss at step 6000: 3.787838
# Average loss at step 8000: 3.686841
# Average loss at step 10000: 3.611727
# Nearest to see: forbid, lahr, il, primetime, greetings, nasir, masamune, classrooms,
# Nearest to between: re, cymbals, luftwaffe, with, computer, lamiaceae, marcellinus, against,
# Nearest to s: his, elaborate, the, simulators, editorial, lcm, nva, and,
# Nearest to years: theft, overheat, consequences, reverses, ratified, emoticons, samurai, binary,
# Nearest to and: or, american, in, but, of, including, pathological, who,
# Nearest to up: both, filming, base, ptolemaic, signature, wedlock, blamed, boudin,
# Nearest to about: ritz, abhidhamma, corum, flee, next, capitalization, emulates, fleets,
# Nearest to called: became, also, thicknesses, freighter, fatherland, abstinence, alternatively, fontsize,
# Nearest to zero: nine, seven, five, six, eight, three, four, two,
# Nearest to have: had, be, has, are, coeducational, urinate, determinism, locrian,
# Nearest to the: a, his, its, their, an, this, s, merging,
# Nearest to first: pills, beast, jeddah, kimi, conte, blackpool, lct, eratosthenes,
# Nearest to state: mammary, wala, makran, goal, swnts, striking, parser, medicine,
# Nearest to known: such, freighter, ergaster, wrapped, aberdeenshire, methodological, cfcs, packers,
# Nearest to people: births, castlevania, devlin, parting, fairgrounds, girl, christi, sabbatical,
# Nearest to his: its, the, their, s, wrinkled, her, intergovernmentalism, diaspora,
# Average loss at step 12000: 3.603072
# Average loss at step 14000: 3.571579
# Average loss at step 16000: 3.407763
# Average loss at step 18000: 3.458392
# Average loss at step 20000: 3.538910
# Nearest to see: classrooms, forbid, masamune, nsa, can, lahr, yeah, primetime,
# Nearest to between: against, with, during, from, in, luftwaffe, computer, re,
# Nearest to s: ockham, nva, suda, calder, sympathies, sagrada, elaborate, routledge,
# Nearest to years: days, theft, emoticons, ratified, overheat, reverses, consequences, works,
# Nearest to and: or, but, isotopes, in, surgical, jespersen, for, from,
# Nearest to up: both, filming, ptolemaic, big, signature, catalina, cuisines, danorum,
# Nearest to about: next, abhidhamma, fleets, cfaf, ritz, corum, emulates, flee,
# Nearest to called: became, fatherland, roberto, abstinence, fontsize, surfing, freighter, also,
# Nearest to zero: five, six, seven, nine, four, eight, two, three,
# Nearest to have: had, has, be, are, were, having, locrian, urinate,
# Nearest to the: their, its, this, an, his, any, a, worshipper,
# Nearest to first: beast, lct, blackpool, second, next, same, pills, kimi,
# Nearest to state: swnts, wala, parser, goal, department, intolerance, striking, mammary,
# Nearest to known: such, regarded, aberdeenshire, methodological, ergaster, freighter, available, tangerine,
# Nearest to people: devlin, fairgrounds, smallville, uppercase, idris, sabbatical, parting, universiti,
# Nearest to his: their, her, its, wrinkled, depends, intergovernmentalism, the, force,
# Average loss at step 22000: 3.501123
# Average loss at step 24000: 3.486817
# Average loss at step 26000: 3.478723
# Average loss at step 28000: 3.480202
# Average loss at step 30000: 3.504878
# Nearest to see: rasputin, forbid, masamune, classrooms, tf, vue, assessment, fountains,
# Nearest to between: with, against, from, during, perverted, in, mug, prodigy,
# Nearest to s: his, elaborate, lint, simulators, sagrada, offended, gladys, disobey,
# Nearest to years: days, months, times, year, theft, emoticons, alcindor, fushimi,
# Nearest to and: or, but, jespersen, however, frederic, from, communicative, who,
# Nearest to up: him, filming, signature, ptolemaic, big, danorum, them, both,
# Nearest to about: next, fleets, abhidhamma, heywood, ritz, emulates, on, actus,
# Nearest to called: roberto, considered, fatherland, tasking, freighter, dram, ronstadt, surfing,
# Nearest to zero: seven, five, eight, six, nine, four, three, two,
# Nearest to have: had, has, were, are, be, having, reminds, represent,
# Nearest to the: their, his, its, any, some, this, a, retroviruses,
# Nearest to first: next, last, second, same, lct, original, kimi, tankers,
# Nearest to state: swnts, wala, department, parser, navy, tireless, study, evasive,
# Nearest to known: regarded, used, available, such, aberdeenshire, methodological, tangerine, ergaster,
# Nearest to people: fortifications, outlaw, smallville, texan, grasshopper, devlin, those, rule,
# Nearest to his: her, their, its, the, our, s, intergovernmentalism, my,
# Average loss at step 32000: 3.501322
# Average loss at step 34000: 3.491760
# Average loss at step 36000: 3.455663
# Average loss at step 38000: 3.298321
# Average loss at step 40000: 3.429558
# Nearest to see: vue, rasputin, refers, nasir, includes, can, fountains, tf,
# Nearest to between: with, during, against, perverted, from, lamiaceae, semifinals, since,
# Nearest to s: lint, his, memex, elaborate, evoked, westernized, downwards, curb,
# Nearest to years: days, months, times, alcindor, year, theft, centuries, fushimi,
# Nearest to and: or, like, but, risking, where, kgb, in, schoolgirl,
# Nearest to up: him, them, out, ptolemaic, big, filming, signature, both,
# Nearest to about: bu, on, abhidhamma, actus, heywood, fleets, salamanders, emulates,
# Nearest to called: considered, roberto, used, amassed, salads, essentially, referred, tasking,
# Nearest to zero: nine, five, seven, eight, six, four, three, two,
# Nearest to have: had, has, were, be, are, having, locrian, fips,
# Nearest to the: their, its, this, a, some, his, any, each,
# Nearest to first: second, last, next, lct, serviced, tojo, blackpool, kimi,
# Nearest to state: swnts, wala, department, goal, navy, tireless, genesis, impaired,
# Nearest to known: used, such, regarded, available, aberdeenshire, doe, tangerine, methodological,
# Nearest to people: men, outlaw, tapu, fortifications, those, smallville, mines, acceptance,
# Nearest to his: their, her, its, our, the, s, mentality, your,
# Average loss at step 42000: 3.438863
# Average loss at step 44000: 3.452564
# Average loss at step 46000: 3.451412
# Average loss at step 48000: 3.348273
# Average loss at step 50000: 3.378758
# Nearest to see: vue, list, pinto, includes, can, include, nasir, rasputin,
# Nearest to between: with, against, during, perverted, from, lamiaceae, mug, prodigy,
# Nearest to s: his, and, szko, elaborate, durian, foodstuff, triumphant, lint,
# Nearest to years: days, months, times, year, alcindor, centuries, collective, fushimi,
# Nearest to and: or, of, in, but, including, s, sanctification, rutherford,
# Nearest to up: out, them, down, him, ptolemaic, back, danorum, into,
# Nearest to about: bu, cabaret, roughly, heywood, dba, over, actus, salamanders,
# Nearest to called: salads, named, amassed, referred, dreamworks, considered, surfing, known,
# Nearest to zero: eight, five, seven, six, nine, four, three, two,
# Nearest to have: had, has, were, be, are, windward, locrian, having,
# Nearest to the: its, their, his, a, this, zout, any, worshipper,
# Nearest to first: last, second, next, final, same, fourth, lct, pills,
# Nearest to state: swnts, wala, department, navy, goal, vizier, detachment, tireless,
# Nearest to known: used, regarded, available, such, doe, aberdeenshire, methodological, endnotes,
# Nearest to people: men, tapu, fortifications, acceptance, devlin, universiti, smallville, outlaw,
# Nearest to his: their, her, its, my, the, intergovernmentalism, our, your,
# Average loss at step 52000: 3.438425
# Average loss at step 54000: 3.424050
# Average loss at step 56000: 3.437286
# Average loss at step 58000: 3.395070
# Average loss at step 60000: 3.396866
# Nearest to see: list, include, assessment, vue, includes, can, pinto, but,
# Nearest to between: with, against, from, around, lamiaceae, perverted, in, during,
# Nearest to s: lint, durian, although, vinton, offended, xiii, kirlian, simulators,
# Nearest to years: days, months, times, year, centuries, weeks, bc, alcindor,
# Nearest to and: or, but, although, than, however, cures, zhaozhou, in,
# Nearest to up: out, down, them, him, ptolemaic, back, off, signature,
# Nearest to about: bu, cabaret, dba, over, actus, leviticus, heywood, gbu,
# Nearest to called: considered, used, named, tasking, dreamworks, referred, muted, known,
# Nearest to zero: five, eight, four, six, seven, nine, three, two,
# Nearest to have: had, has, were, are, having, be, sickly, locrian,
# Nearest to the: a, its, their, this, any, garbled, some, his,
# Nearest to first: last, second, next, final, same, maa, only, conte,
# Nearest to state: swnts, navy, department, goal, wala, vizier, condition, study,
# Nearest to known: used, regarded, such, available, serve, doe, tangerine, aberdeenshire,
# Nearest to people: men, members, those, fortifications, outlaw, jews, tapu, texan,
# Nearest to his: her, their, its, my, your, our, wrinkled, mentality,
# Average loss at step 62000: 3.240196
# Average loss at step 64000: 3.252133
# Average loss at step 66000: 3.401461
# Average loss at step 68000: 3.393687
# Average loss at step 70000: 3.361701
# Nearest to see: list, includes, include, pinto, vue, gr, masamune, sanders,
# Nearest to between: with, among, within, around, from, against, during, semifinals,
# Nearest to s: lint, and, asymptotes, lempira, chagos, xxxviii, boomerangs, xiii,
# Nearest to years: days, months, times, year, weeks, centuries, bc, decades,
# Nearest to and: or, but, which, however, while, dedham, untranslated, of,
# Nearest to up: out, them, down, back, him, off, ptolemaic, suite,
# Nearest to about: over, dba, fleets, bu, zooming, salamanders, that, kuti,
# Nearest to called: considered, named, referred, muted, skies, cara, known, alamein,
# Nearest to zero: five, six, four, eight, seven, nine, three, two,
# Nearest to have: had, has, are, were, having, be, fips, locrian,
# Nearest to the: its, their, a, this, any, each, these, your,
# Nearest to first: second, last, next, same, third, final, original, earliest,
# Nearest to state: swnts, navy, government, vav, oxford, department, speaker, wala,
# Nearest to known: used, regarded, such, available, defined, aberdeenshire, serve, doe,
# Nearest to people: men, members, those, children, smallville, tapu, christians, jews,
# Nearest to his: her, their, its, my, your, our, mentality, wrinkled,
# Average loss at step 72000: 3.375822
# Average loss at step 74000: 3.344780
# Average loss at step 76000: 3.309264
# Average loss at step 78000: 3.354876
# Average loss at step 80000: 3.377465
# Nearest to see: includes, include, list, but, nasir, marsilio, links, references,
# Nearest to between: with, within, around, among, semifinals, from, in, against,
# Nearest to s: his, lint, pagos, foodstuff, cyclist, isbn, undertook, durian,
# Nearest to years: days, months, times, weeks, year, centuries, decades, bc,
# Nearest to and: or, monochrome, including, but, meticulously, ed, relieves, printings,
# Nearest to up: out, down, them, off, him, back, ptolemaic, together,
# Nearest to about: dba, approximately, over, kuti, macroeconomic, bu, outnumber, cabaret,
# Nearest to called: considered, named, referred, known, muted, used, cara, essentially,
# Nearest to zero: five, six, seven, four, eight, three, two, nine,
# Nearest to have: had, has, are, were, having, be, locrian, represent,
# Nearest to the: their, its, his, a, another, those, this, manichaeism,
# Nearest to first: second, last, next, same, third, final, original, fourth,
# Nearest to state: government, city, swnts, speaker, navy, tireless, states, county,
# Nearest to known: used, regarded, available, serve, defined, such, classified, doe,
# Nearest to people: men, children, individuals, members, women, those, jews, transference,
# Nearest to his: her, their, its, my, our, your, the, s,
# Average loss at step 82000: 3.408482
# Average loss at step 84000: 3.408662
# Average loss at step 86000: 3.385612
# Average loss at step 88000: 3.351237
# Average loss at step 90000: 3.362987
# Nearest to see: includes, list, references, include, marsilio, links, seo, nasir,
# Nearest to between: with, within, against, among, around, during, semifinals, from,
# Nearest to s: his, her, whose, foodstuff, pagos, our, szko, xiii,
# Nearest to years: days, months, weeks, year, centuries, times, decades, hours,
# Nearest to and: or, but, including, dde, while, bongo, cures, daffodils,
# Nearest to up: out, down, them, off, back, him, ptolemaic, together,
# Nearest to about: dba, macroeconomic, kuti, over, powering, ritz, broker, bu,
# Nearest to called: considered, referred, named, used, known, muted, tasking, duly,
# Nearest to zero: five, eight, six, seven, four, nine, two, three,
# Nearest to have: had, has, were, are, be, having, tend, provide,
# Nearest to the: its, their, this, his, a, whose, our, any,
# Nearest to first: last, second, next, same, earliest, original, third, final,
# Nearest to state: swnts, city, speaker, government, navy, tireless, vizier, happenings,
# Nearest to known: used, regarded, available, such, serve, doe, defined, classified,
# Nearest to people: men, children, members, women, individuals, those, christians, survivors,
# Nearest to his: her, their, its, my, our, your, s, the,
# Average loss at step 92000: 3.396125
# Average loss at step 94000: 3.255213
# Average loss at step 96000: 3.356135
# Average loss at step 98000: 3.244933
# Average loss at step 100000: 3.357339
# Nearest to see: includes, references, list, include, can, marsilio, eased, disinterested,
# Nearest to between: with, against, among, around, within, through, during, over,
# Nearest to s: offended, his, whose, your, isbn, foodstuff, wai, brentano,
# Nearest to years: days, months, year, weeks, centuries, times, decades, hours,
# Nearest to and: or, but, although, of, however, like, while, including,
# Nearest to up: out, off, him, down, them, back, ptolemaic, together,
# Nearest to about: kuti, macroeconomic, powering, outnumber, on, dba, wahhabism, over,
# Nearest to called: referred, named, amassed, used, considered, muted, volley, known,
# Nearest to zero: five, eight, four, seven, six, nine, three, two,
# Nearest to have: had, has, are, were, contain, provide, be, having,
# Nearest to the: their, your, its, a, his, our, each, subscribed,
# Nearest to first: next, last, second, third, same, final, fourth, original,
# Nearest to state: swnts, city, genesis, happenings, speaker, vizier, oxford, detachment,
# Nearest to known: regarded, used, such, available, serve, defined, possible, classified,
# Nearest to people: men, children, individuals, women, jews, those, members, christians,
# Nearest to his: her, their, my, its, our, your, the, s,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch_cbow(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size // num_skips, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[target]
    labels[i, 0] = buffer[skip_window]

    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch.reshape(8)])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8/num_skips)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#     labels: ['originated', 'as', 'a', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['term', 'anarchism', 'originated', 'a', 'of', 'as', 'originated', 'term']
#     labels: ['as', 'a']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size // num_skips, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  tmp_embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  segment_ids = list(range(batch_size))
  segment_ids[:] = [int(x / num_skips) for x in segment_ids]
  embed = tf.segment_sum(tmp_embed, segment_ids)
    
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.255236
# Nearest to american: congestive, aaron, toxicology, cuisines, rebuttal, mutilation, extrinsic, durant,
# Nearest to but: ptah, ceding, anechoic, convergence, bornu, king, andree, chlorophyll,
# Nearest to b: maui, sorts, stupidity, porting, lakshmi, glitch, madrigal, malwa,
# Nearest to some: prairie, sadly, cannae, mvp, elementary, studios, harnesses, coughing,
# Nearest to that: worldview, flourished, retailers, mind, heisei, stacked, decalogue, bastions,
# Nearest to eight: adin, georg, fainting, qazaqstan, biconditional, payback, apologists, magnetosphere,
# Nearest to will: antiarrhythmic, wrinkled, joab, deliberative, normandie, solvable, elrond, stamina,
# Nearest to up: monumental, prisoner, methadone, quakers, catabolism, arameans, bewildering, manoeuvre,
# Nearest to so: esperanto, undergoing, ei, economy, inositol, blown, hedley, honours,
# Nearest to many: amicus, huike, foxy, derrida, unreasonable, barents, situated, baraka,
# Nearest to however: hiss, qh, parabolic, rats, quarry, tomb, tabriz, derision,
# Nearest to while: morpheme, overzealous, gropius, pia, answering, zug, jar, deterrence,
# Nearest to called: reclaiming, plummer, roddick, herd, ina, buyer, hyphen, interfacing,
# Nearest to such: diatessaron, relationships, rohmer, baggins, motionless, specialising, pools, priming,
# Nearest to history: befall, savanna, leland, silently, adt, ferrigno, robins, scales,
# Nearest to use: ramjet, problems, roast, rides, frites, defends, next, ascertain,
# Average loss at step 2000: 4.209179
# Average loss at step 4000: 3.644468
# Average loss at step 6000: 3.541454
# Average loss at step 8000: 3.383223
# Average loss at step 10000: 3.295239
# Nearest to american: english, cartographic, respects, regulatory, cuisines, ircii, foley, congestive,
# Nearest to but: however, thierry, fiddler, vinci, tread, will, could, see,
# Nearest to b: maui, d, deus, cpsu, maior, fiftieth, myrtle, slashing,
# Nearest to some: many, other, earmarked, any, these, nucleon, oblique, aversion,
# Nearest to that: acm, rutger, which, colloquium, buson, hairy, what, microseconds,
# Nearest to eight: five, seven, nine, six, three, four, zero, two,
# Nearest to will: would, can, could, may, must, might, should, cannot,
# Nearest to up: gorey, him, squalor, down, cleaves, methadone, holding, sucking,
# Nearest to so: nhk, definability, brighton, more, refining, tibeto, grayson, hopkins,
# Nearest to many: some, several, various, other, most, magen, slavonic, asa,
# Nearest to however: but, epithelial, neopagans, fas, albinus, there, koko, giacomo,
# Nearest to while: zug, although, gropius, administrated, whitcomb, swamped, peterborough, discourages,
# Nearest to called: enrichment, interventions, rooster, polyidus, mtu, ferrer, alliterative, trebizond,
# Nearest to such: well, asserting, these, known, welch, anaphase, absolutist, onlookers,
# Nearest to history: cleartype, anchorage, conferred, mamluk, legis, savanna, verrocchio, lordship,
# Nearest to use: nonmetals, tammany, chronically, byproduct, circe, cemented, sassanid, death,
# Average loss at step 12000: 3.273173
# Average loss at step 14000: 3.245463
# Average loss at step 16000: 3.030039
# Average loss at step 18000: 3.060350
# Average loss at step 20000: 3.155701
# Nearest to american: british, french, australian, swedish, canadian, swiss, whitacre, riches,
# Nearest to but: however, though, although, that, venlo, did, do, and,
# Nearest to b: d, paleo, advertiser, symonds, fondness, gigi, porting, scullin,
# Nearest to some: many, several, these, those, other, any, most, habibullah,
# Nearest to that: which, polymers, however, but, acm, what, when, there,
# Nearest to eight: nine, seven, five, six, four, three, two, zero,
# Nearest to will: would, can, could, may, should, must, might, cannot,
# Nearest to up: him, down, back, them, ccc, out, holding, squalor,
# Nearest to so: steeple, incorruptible, kingsley, oilseed, later, more, too, sometimes,
# Nearest to many: several, some, these, various, other, those, peerage, different,
# Nearest to however: but, and, that, there, though, while, when, although,
# Nearest to while: although, when, after, where, during, however, though, but,
# Nearest to called: used, known, see, forget, vault, named, ferrer, founded,
# Nearest to such: well, these, known, anaphase, asserting, schoolhouse, caveats, revolutionize,
# Nearest to history: majority, pastiches, elaborates, shops, concept, practice, age, unites,
# Nearest to use: masts, church, most, escape, form, collation, determination, chronically,
# Average loss at step 22000: 3.123513
# Average loss at step 24000: 3.074699
# Average loss at step 26000: 3.056890
# Average loss at step 28000: 3.063004
# Average loss at step 30000: 3.088120
# Nearest to american: australian, english, british, canadian, german, french, african, italian,
# Nearest to but: however, although, do, pylons, and, while, insist, if,
# Nearest to b: d, fruitless, formidable, widdecombe, reconciling, finds, ibrahim, organize,
# Nearest to some: many, these, several, any, various, most, the, those,
# Nearest to that: what, polymers, which, rutger, imperfectly, churchland, acm, fas,
# Nearest to eight: nine, six, five, seven, four, three, zero, two,
# Nearest to will: would, could, can, must, may, might, should, shall,
# Nearest to up: down, him, them, off, back, out, methadone, squalor,
# Nearest to so: comments, refining, very, kingsley, too, incorruptible, sees, essen,
# Nearest to many: several, some, those, various, few, these, most, themselves,
# Nearest to however: but, although, though, when, while, if, sources, notably,
# Nearest to while: although, during, however, like, but, though, when, kabir,
# Nearest to called: used, named, known, discovered, termed, vault, considered, nasir,
# Nearest to such: well, these, known, anaphase, asserting, regarded, schoolhouse, follows,
# Nearest to history: concept, depravity, sira, practice, interests, leviticus, roc, scorpio,
# Nearest to use: collation, precautions, part, names, accesses, masts, lack, caer,
# Average loss at step 32000: 3.076129
# Average loss at step 34000: 3.047246
# Average loss at step 36000: 3.004233
# Average loss at step 38000: 2.791188
# Average loss at step 40000: 2.987053
# Nearest to american: australian, british, italian, russian, indian, french, pacific, german,
# Nearest to but: and, although, however, webpages, among, expenditure, fantastic, signifies,
# Nearest to b: d, c, r, j, UNK, fruitless, bruised, h,
# Nearest to some: many, any, these, certain, several, those, various, this,
# Nearest to that: which, what, however, pyrenees, who, rutger, acm, where,
# Nearest to eight: nine, seven, four, six, five, zero, three, two,
# Nearest to will: would, must, could, can, may, should, might, cannot,
# Nearest to up: off, out, down, him, them, back, gorey, koza,
# Nearest to so: comments, incorruptible, it, refining, license, buoyancy, malaria, steeple,
# Nearest to many: several, some, those, various, both, these, dacko, most,
# Nearest to however: but, that, although, defun, octopus, temair, today, though,
# Nearest to while: although, when, after, like, where, terminates, gave, strickland,
# Nearest to called: named, categorize, used, imaginary, accompany, ferrer, considered, now,
# Nearest to such: these, well, including, known, anaphase, asserting, certain, shutting,
# Nearest to history: concept, keiretsu, policy, period, yesterday, autistic, habilis, talents,
# Nearest to use: kind, form, sense, share, version, styne, neg, exception,
# Average loss at step 42000: 2.985208
# Average loss at step 44000: 2.991396
# Average loss at step 46000: 2.977377
# Average loss at step 48000: 2.876664
# Average loss at step 50000: 2.891624
# Nearest to american: australian, european, communist, russian, indian, italian, americans, canadian,
# Nearest to but: although, however, and, while, though, when, retro, firewire,
# Nearest to b: d, r, inserts, solidifying, embarking, frederick, distinguishes, c,
# Nearest to some: many, several, these, indentation, various, both, most, any,
# Nearest to that: which, however, rutger, lexis, errands, hewson, what, acm,
# Nearest to eight: six, seven, nine, four, three, five, zero, two,
# Nearest to will: must, may, could, would, can, should, might, cannot,
# Nearest to up: off, out, down, back, them, away, gorey, him,
# Nearest to so: too, sometimes, before, eliyahu, gestae, tights, buoyancy, mcdonald,
# Nearest to many: some, several, various, numerous, both, few, those, most,
# Nearest to however: although, but, while, that, where, though, when, defun,
# Nearest to while: although, when, where, however, but, after, before, though,
# Nearest to called: named, used, administratively, bai, mcghee, categorize, described, contented,
# Nearest to such: well, known, anaphase, certain, these, described, many, having,
# Nearest to history: keiretsu, coordinators, yesterday, list, hall, giraffe, centrale, archaically,
# Nearest to use: issue, sense, end, experience, list, introduction, thunderball, exception,
# Average loss at step 52000: 2.954075
# Average loss at step 54000: 2.933239
# Average loss at step 56000: 2.953430
# Average loss at step 58000: 2.880749
# Average loss at step 60000: 2.900884
# Nearest to american: european, russian, australian, italian, indian, canadian, america, african,
# Nearest to but: however, although, though, and, montane, bacchus, sag, erickson,
# Nearest to b: r, c, d, j, h, m, dwt, twister,
# Nearest to some: many, several, any, these, certain, both, various, this,
# Nearest to that: which, what, it, polymers, acm, pyrenees, goldwater, nez,
# Nearest to eight: nine, six, seven, four, three, five, zero, two,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to up: out, off, down, back, him, them, attain, away,
# Nearest to so: too, eliyahu, gestae, license, astro, buoyancy, persuades, netsplit,
# Nearest to many: some, several, various, numerous, most, such, these, few,
# Nearest to however: but, though, since, although, occurred, semicolon, epithelial, world,
# Nearest to while: when, before, although, after, martyn, wore, gays, got,
# Nearest to called: named, known, used, considered, described, ferrer, uri, required,
# Nearest to such: well, many, known, certain, asserting, these, anaphase, regarded,
# Nearest to history: development, list, glider, dominates, coordinators, yesterday, logistic, course,
# Nearest to use: practice, usage, shatt, know, sense, styne, disposal, cease,
# Average loss at step 62000: 2.678051
# Average loss at step 64000: 2.706108
# Average loss at step 66000: 2.877039
# Average loss at step 68000: 2.891731
# Average loss at step 70000: 2.834493
# Nearest to american: australian, america, canadian, african, americans, indian, european, italian,
# Nearest to but: however, and, hula, see, though, which, signifies, that,
# Nearest to b: r, j, h, twister, f, d, dwt, pickford,
# Nearest to some: many, several, various, multiple, numerous, all, certain, this,
# Nearest to that: which, however, what, this, rutger, arrhythmia, typically, also,
# Nearest to eight: nine, six, seven, five, four, zero, three, two,
# Nearest to will: would, may, should, could, must, can, might, cannot,
# Nearest to up: back, off, out, them, down, attain, hydrodynamics, him,
# Nearest to so: sometimes, too, magnetization, ndnis, oyly, how, therefore, compactness,
# Nearest to many: some, several, numerous, various, all, most, those, much,
# Nearest to however: but, though, that, where, although, when, which, freenet,
# Nearest to while: although, where, when, and, like, before, unlike, after,
# Nearest to called: described, known, named, termed, basically, referred, kaunda, considered,
# Nearest to such: these, known, well, anaphase, opposed, asserting, follows, certain,
# Nearest to history: list, biography, beatified, logistic, honeys, keiretsu, ulaanbaatar, latter,
# Nearest to use: shatt, usage, form, loup, share, practice, styne, indication,
# Average loss at step 72000: 2.868249
# Average loss at step 74000: 2.821280
# Average loss at step 76000: 2.819961
# Average loss at step 78000: 2.830719
# Average loss at step 80000: 2.851958
# Nearest to american: international, australian, americans, canadian, cologne, british, rugby, russian,
# Nearest to but: however, although, signifies, and, or, though, insist, pero,
# Nearest to b: d, twister, montferrat, j, inserts, r, businessman, lulach,
# Nearest to some: many, most, numerous, several, various, certain, those, these,
# Nearest to that: which, however, what, microseconds, coping, how, where, rutger,
# Nearest to eight: nine, six, five, seven, four, three, zero, two,
# Nearest to will: would, could, can, may, might, must, cannot, should,
# Nearest to up: off, back, out, down, them, away, attain, together,
# Nearest to so: too, sichuan, oyly, khans, how, swallowing, concluded, ndnis,
# Nearest to many: some, several, numerous, various, all, most, these, both,
# Nearest to however: but, although, though, did, that, when, including, spilled,
# Nearest to while: although, when, after, though, including, drew, and, or,
# Nearest to called: named, used, known, referred, termed, considered, beckham, uri,
# Nearest to such: well, follows, these, anaphase, known, defined, regarded, forseti,
# Nearest to history: legend, logistic, coordinators, partying, timing, wavelength, aspects, list,
# Nearest to use: share, form, lack, intermediaries, shatt, because, rise, support,
# Average loss at step 82000: 2.884491
# Average loss at step 84000: 2.892476
# Average loss at step 86000: 2.859825
# Average loss at step 88000: 2.801223
# Average loss at step 90000: 2.822879
# Nearest to american: australian, canadian, international, italian, scottish, russian, british, traditional,
# Nearest to but: however, and, though, sniff, probably, tian, they, although,
# Nearest to b: twister, kohen, businessman, similar, y, dismal, j, pillow,
# Nearest to some: many, several, certain, all, most, these, numerous, those,
# Nearest to that: which, rutger, however, what, kwa, bartolomeo, how, compost,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to will: would, might, can, could, cannot, must, should, may,
# Nearest to up: off, out, back, down, away, together, them, him,
# Nearest to so: too, how, sees, translational, upholds, kyoto, reminds, shakes,
# Nearest to many: some, several, numerous, all, various, those, certain, most,
# Nearest to however: but, though, although, and, altair, if, when, that,
# Nearest to while: when, although, after, during, before, though, and, were,
# Nearest to called: known, used, named, considered, misdiagnosed, described, referred, sold,
# Nearest to such: well, known, follows, certain, stig, identified, described, viewed,
# Nearest to history: list, logistic, wavelength, mechanization, version, reign, recognition, aspects,
# Nearest to use: share, usage, practice, manhood, application, mirc, refinement, because,
# Average loss at step 92000: 2.861140
# Average loss at step 94000: 2.683339
# Average loss at step 96000: 2.830611
# Average loss at step 98000: 2.699671
# Average loss at step 100000: 2.817573
# Nearest to american: canadian, australian, italian, scottish, swiss, british, mexican, knudsen,
# Nearest to but: however, and, although, though, including, while, leaving, irritant,
# Nearest to b: d, lulach, nsson, twister, lessing, pohjola, moonraker, swabia,
# Nearest to some: many, several, these, any, numerous, all, those, gleaned,
# Nearest to that: which, what, however, gillette, why, who, this, serine,
# Nearest to eight: nine, seven, five, four, six, three, zero, two,
# Nearest to will: would, might, could, may, can, must, cannot, should,
# Nearest to up: off, out, back, attain, together, him, down, scilly,
# Nearest to so: too, then, thus, muse, otherwise, informally, later, rhine,
# Nearest to many: some, several, numerous, various, these, those, all, such,
# Nearest to however: but, although, though, and, when, including, that, needed,
# Nearest to while: although, when, before, and, after, but, though, besides,
# Nearest to called: named, referred, termed, used, known, based, bai, excerpted,
# Nearest to such: known, well, many, these, regarded, including, serve, opposed,
# Nearest to history: wavelength, honeys, mechanization, sprawling, list, logistic, bust, biography,
# Nearest to use: usage, application, form, share, importance, sense, introduction, intermediaries,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# <img src="data:image/png;base64,...">
